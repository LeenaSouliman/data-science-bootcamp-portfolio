# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  |   data from cameras (images), point clouds, ultrasonic sensors and radar|         Rear and front cameras, light sensors on the roof and LiDAR light waves are reflected by objects and therefore able to detect and track obstacles/objects, road signs and lane detection. The radar is for collision avoidance and the digital map is to keep track of location and thus speed limit and crossings.
# | 1.2  |   Users rating and feedback          |   Refines the recommendation algorithms to prioritise content similar to highly rated or positively-reviewed titles.
# | 1.3  |  Temporal data - time taken to write signature           |    Timing analysis for signature authentication, identifying patterns or anomalies. Analysing historical data to identify trends, patterns, and anomalies over time.
# | 1.4  |    Medical test results- blood test, imaging, scans |  Collaction and relationship conclusion based on datasets of symptoms and disease to draw diagnostic recommendation or confirmation of condition based on a collection of results and medical guidelines. Used as a preventative measure          |

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata
# * 2.2 Forecasting the stock price of a company based on historical data and market trends
# * 2.3 Sorting images of animals into different species based on their visual features
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results

# %% [markdown]
# 2. Answer here
# * 2.1 Classification.
#
#     This is because the goal is to predict the category in which the email fits into two distinct categories, either promotional or social, based on their content and metadata. The programme will learn patterns and relationships between input features and classes. Based on this, the programme will be able to classify and make predictions on new unseen emails through the learnt patterns.
#
# * 2.2 Regression.
#
#     This is because the aim here is to predict a continuous value, future time point of stock price, based on historical data and market trends input. The model will learn patterns and relationships in historical data to make predictions about stock prices. The predicted value is the continuous numeric value.
#
# * 2.3 Classification.
#
#     This is because the goal is to predict the species categorised based on phenotypical features i.e. colour, shape, and size.  This allows the extrapolated data from animal images to be assigned to species of animal based on features. The model will be trained on a dataset with images labelled with the corresponding animal species. The models learn the patterns in the visual features that distinguish between different species and make predictions on new, unseen images to classify them into the appropriate species.
#
# * 2.4 Classification.
#
#     This is because the goal is to predict the likelihood of having a particular disease, which is definite and labelled, based on the input of the patient's medical history such as symptoms and test results. The algorithm deployed will learn to recognise patterns in the patient's medical history and map them to the likelihood of having the disease. The model will utilise a historical dataset where each patient's medical history is labelled with the presence or absence of disease, to which the model will then learn the patterns in medical history features that distinguish between patients with and without the disease. The model will then be able to make predictions on new unseen patients

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised.
# This is because it will involve training the model on unlabeled data to identify patterns or structures within the data without explicit guidance or supervision. Moreover, unsupervised techniques will identify outliers from normal behaviour in the data without relying on labelled examples of anomalies.
#
# * 3.2 Supervised.
# This is because the model will learn from the labelled dataset, where the input features such as historical transactions and customer demographics and associated with customer lifetime value. The model will learn a mapping from the input features to the target labels, which allows the model to make predictions on new, unseen data.
#
# * 3.3 Unsupervised.
# This is because the model will find patterns in the data without guidance from unlabeled data. As a result,  classes will be serpated and formed.
#
# * 3.4 Unsupervised.
# This is because the algorithm will analyse the patterns within the data without explicit labels or pre-labelled examples of themes and will discover patterns in the data.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 Inappropriate,this is beacuse the most of the dataset is pre-lablled and so supervised algorithm would fit best.
# * 4.2 Appropriate,
# this is because a small portion of data is labelled and therefore abundance of unlabelled data.
# * 4.3 Inappropriate,
#     this is beacuse the majority of emails are labelled and so supervised would be best fit for this.
# * 4.4 Appropriate,
#     this is because there is a mixture of labelled data and unlabeled data to train the model. The output is classified as either being able to obtain or denied as well as factoring in historical credit-related information.
